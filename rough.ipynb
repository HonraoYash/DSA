# %%
string = "1.txt(abcd)"
list = string.split('(')
list = list[1].split(')')
print(list)
# Out:
# ['abcd', '']

# %%
defaultdict(<class 'list'>, {'abcd': ['root/a/1.txt', 'root/c/3.txt'], 'efgh': ['root/a/2.txt', 'root/c/d/4.txt', 'root/4.txt']})
